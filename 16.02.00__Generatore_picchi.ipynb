# %% [markdown]
# # Generatore picchi
#
# Questo script genera campioni di segnale più fondo simulati.
#
# **Non è stato fornito agli studenti prima della lezione. Sono stati forniti solo i dataset chiedendo di fare dei fit con diversi modelli di segnale e fondo**

# %%
from matplotlib import pyplot as plt
import numpy as np
import math

np.random.seed(12345)

# %%
def plot_data(n_bins=50, x_max=50, filename="data/fit-data.txt"):
    fig, ax = plt.subplots(figsize=(9,6),dpi=100)
    x_range = (0, x_max)
    data_y, bins, patches = ax.hist(evt_x, n_bins, range=x_range, density=False, 
        histtype=u'step', edgecolor='b', linewidth=2, label='histogram')
    ax.hist(evt_x, n_bins, range=x_range, density=False, color='b', alpha=0.2)
    ax.scatter(evt_x, np.full_like(evt_x, 0.5), marker='o', color='r', s=10, alpha=0.2, linewidth=0, label='entries')
    plt.xlabel('x')
    plt.ylabel('$\Delta N/\Delta x$')
    plt.xlim(0, x_max)
    plt.legend()
    plt.show()
    np.savetxt(filename, evt_x)

# %% [markdown]
# Singolo picco su fondo esponenziale

# %%
nexp_sig, nexp_bkg1, nexp_bkg2 = 90, 300, 50
l = 12
mu, sigma = 10, 1.5
n_sig = np.random.poisson(nexp_sig)
n_bkg1 = np.random.poisson(nexp_bkg1)
n_bkg2 = np.random.poisson(nexp_bkg2)
sig_x = np.array([np.random.normal(loc=mu, scale=sigma) for i in range(n_sig)])
bkg1_x = np.array([np.random.exponential(scale=l) for i in range(n_bkg1)])
bkg2_x = np.array([np.random.uniform(0, 100) for i in range(n_bkg2)])
evt_x = np.concatenate([sig_x, bkg1_x, bkg2_x])
np.random.shuffle(evt_x)
plot_data(100, 100, filename="data/fit-data-1.txt")

# %% [markdown]
# Due picchi, ben separati.

# %%
nexp_sig1, nexp_sig2, nexp_bkg1, nexp_bkg2 = 90, 60, 300, 280
l = 25
mu1, sigma1, mu2, sigma2 = 16, 1.5, 34, 2.3
n_sig1, n_sig2 = np.random.poisson(nexp_sig1), np.random.poisson(nexp_sig2)
n_bkg1 = np.random.poisson(nexp_bkg1)
n_bkg2 = np.random.poisson(nexp_bkg2)
sig1_x = np.array([np.random.normal(loc=mu1, scale=sigma1) for i in range(n_sig1)])
sig2_x = np.array([np.random.normal(loc=mu2, scale=sigma2) for i in range(n_sig2)])
bkg1_x = np.array([np.random.exponential(scale=l) for i in range(n_bkg1)])
bkg2_x = np.array([np.random.uniform(0, 150) for i in range(n_bkg2)])
evt_x = np.concatenate([sig1_x, sig2_x, bkg1_x, bkg2_x])
evt_x = evt_x[evt_x<150]
np.random.shuffle(evt_x)
plot_data(150, 150, filename="data/fit-data-2.txt")

# %% [markdown]
# Due picchi con sovrapposizione

# %%
nexp_sig1, nexp_sig2, nexp_bkg1, nexp_bkg2 = 260, 240, 600, 160
l = 50
mu1, sigma1, mu2, sigma2 = 65, 5.7, 84, 7.6
n_sig1, n_sig2 = np.random.poisson(nexp_sig1), np.random.poisson(nexp_sig2)
n_bkg1 = np.random.poisson(nexp_bkg1)
n_bkg2 = np.random.poisson(nexp_bkg2)
sig1_x = np.array([np.random.normal(loc=mu1, scale=sigma1) for i in range(n_sig1)])
sig2_x = np.array([np.random.normal(loc=mu2, scale=sigma2) for i in range(n_sig2)])
bkg1_x = np.array([np.random.exponential(scale=l) for i in range(n_bkg1)])
bkg2_x = np.array([np.random.uniform(0, 200) for i in range(n_bkg2)])
evt_x = np.concatenate([sig1_x, sig2_x, bkg1_x, bkg2_x])
np.random.shuffle(evt_x)
plot_data(200, 200, filename="data/fit-data-3.txt")

# %% [markdown]
# Singolo picco con forma di doppia gaussiana.

# %%
nexp_sig1, nexp_sig2, nexp_bkg1, nexp_bkg2 = 260, 340, 600, 600
l = 50
mu, sigma1, sigma2 = 65, 3.4, 10
n_sig1, n_sig2 = np.random.poisson(nexp_sig1), np.random.poisson(nexp_sig2)
n_bkg1 = np.random.poisson(nexp_bkg1)
n_bkg2 = np.random.poisson(nexp_bkg2)
sig1_x = np.array([np.random.normal(loc=mu, scale=sigma1) for i in range(n_sig1)])
sig2_x = np.array([np.random.normal(loc=mu, scale=sigma2) for i in range(n_sig2)])
bkg1_x = np.array([np.random.exponential(scale=l) for i in range(n_bkg1)])
bkg2_x = np.array([np.random.uniform(0, 200) for i in range(n_bkg2)])
evt_x = np.concatenate([sig1_x, sig2_x, bkg1_x, bkg2_x])
evt_x = evt_x[evt_x<200]
np.random.shuffle(evt_x)
plot_data(200, 200, filename="data/fit-data-4.txt")

# %% [markdown]
# Read data

# %%
data=np.loadtxt("data/fit-data-1.txt")
print(data)
# Out:
# [1.98046374e+00 1.87878393e+00 4.48379425e+01 3.50009419e+01
#  7.70261038e+00 2.68201345e+01 7.20126561e+00 5.69970272e+00
#  2.69565670e+00 3.58754794e+00 2.05735029e+00 1.01048150e+01
#  1.08402179e+01 3.73037934e+00 1.62417320e+01 8.10109826e+00
#  5.56600559e+00 1.37518664e+01 1.29881204e+01 1.04993241e+01
#  1.45744217e+01 8.75326969e+00 6.36423611e+00 1.20262135e+01
#  3.95225674e+01 3.14411807e+00 1.15752700e+00 2.78707371e+00
#  2.41173430e+01 3.87295953e+00 7.59965486e+00 1.12794475e+01
#  5.41339901e+00 9.98220760e+00 1.57230452e+01 1.11053182e-01
#  8.62110766e+00 1.15072174e+01 1.93392139e+00 1.49719337e+01
#  3.30647680e+01 1.00769742e+01 5.01967579e-01 1.14713927e+01
#  6.84257094e+00 8.80009825e+00 2.91466405e+00 8.60649070e+00
#  8.64781024e-01 3.25930843e+01 1.05669762e+01 1.16119340e+01
#  1.47570124e+01 4.57658828e+01 3.28915548e+01 4.22282303e+00
#  6.43636813e+01 8.91067976e+00 3.51868477e+01 1.03343433e+01
#  1.78904682e+01 5.47379117e+00 2.48244154e+00 1.11535339e+01
#  1.12758866e+01 4.96781827e-01 7.11512429e+01 6.35557887e+00
#  2.57767043e+01 1.31640598e+01 2.08110448e+01 8.86917020e+00
#  4.67018221e+00 2.01304950e+00 2.03578209e+00 1.12250604e+01
#  3.53730268e+01 8.41335506e-01 1.67396929e+00 3.28438571e+00
#  1.06504144e+01 1.08774546e+01 3.18738295e+00 2.81299380e+01
#  8.81552586e+00 9.92407758e+00 8.70886390e+00 1.04589700e+01
#  2.20407679e+01 2.67700051e+01 1.17264124e+01 1.16671507e+01
#  4.21285988e+01 1.04295246e+01 1.27945676e+01 8.87720268e+00
#  3.87484890e+01 6.95617355e+00 9.20689776e+00 1.00014104e+01
#  2.03983619e+01 1.11132820e+01 1.01771646e+01 9.58499859e+01
#  3.05193771e+01 2.93146021e+00 1.13296440e+01 5.50834086e+00
#  3.11074804e+00 1.04539203e+01 1.00750140e+01 1.19907919e+01
#  2.44094415e+00 8.19841386e+00 1.17403456e+00 1.16430851e+01
#  3.15702638e+01 2.57095418e+01 1.45881481e+01 1.70371490e+01
#  9.06658866e+00 1.11928797e+01 4.16732027e-01 7.44415665e+00
#  1.38561425e+01 4.75413703e+00 4.19091657e+00 3.74192596e+01
#  4.11148384e+00 3.65370255e+00 6.83730957e+00 7.26152302e+00
#  3.82527266e+00 1.23321568e+01 1.32230527e+01 1.91439442e+01
#  3.71425837e+01 1.22885655e-01 1.41278815e+01 8.46815871e+00
#  2.30329678e+01 5.70851553e+01 8.92968402e+00 9.27614103e+00
#  2.20773911e+01 6.99754404e+00 8.56619672e+00 8.05961540e+00
#  9.11576847e+00 6.24180649e+01 2.48302507e+00 1.01393618e+01
#  1.02290149e+01 3.29213338e-01 7.32486794e+00 1.10350028e+01
#  4.81618483e+00 6.19841986e+00 6.54364918e+00 8.96480797e+00
#  7.74049605e+00 5.34216644e+00 1.28714727e-03 5.55377336e+00
#  2.62420774e+00 6.41510591e+00 3.51660520e+01 8.84819347e-01
#  6.59245212e+00 4.36618362e+01 4.93540933e+00 1.70542097e+01
#  1.55049509e+01 1.18319983e+01 7.65930359e+00 5.24057129e+00
#  7.89032425e+01 1.00798356e+01 5.70647713e+00 2.68330668e+01
#  6.46087179e+00 9.69210298e+00 2.88447388e+00 4.21322342e+00
#  1.07154775e+01 2.00152470e-01 2.06149309e+01 5.15011570e+00
#  8.14398696e+01 1.97958921e+00 7.64730045e+01 1.15107840e+01
#  6.37974421e+00 8.40473133e+00 7.85857538e+00 9.19038783e+00
#  1.63730849e+00 3.43979210e+00 6.21060328e+01 1.13949531e+01
#  8.15251021e+00 1.15161054e+01 1.49425455e+01 4.79569497e+00
#  1.20293753e+01 7.99322947e-01 3.45101562e+00 6.86678463e+01
#  2.91819794e+00 6.63931014e+00 7.68700671e+00 2.67704655e+01
#  1.41675291e+01 3.01531362e+01 9.27475972e-01 6.62020758e+01
#  8.17254704e+00 1.04969285e+01 5.61358564e+00 1.48810556e+01
#  1.46686331e+01 4.01854121e+00 3.01050403e+00 1.53357029e+01
#  9.34214540e+00 1.65018668e+01 1.93316000e+01 2.19062052e+01
#  9.95100379e+00 1.53379471e+01 1.15808796e-02 8.35352152e+01
#  2.69610030e+00 2.83834211e-01 4.43268828e+01 4.88462574e+00
#  7.65151406e+00 9.89915097e+00 2.91632633e+00 2.91052617e+01
#  1.03949215e+01 1.75368142e+01 1.02823160e+01 1.33677107e+01
#  1.01861819e+01 1.43330862e+01 1.76999397e+00 1.53360315e+00
#  3.53417923e+00 5.11910273e+00 6.44016689e-01 6.52646462e+00
#  1.51349183e+01 1.37696558e+01 1.91822555e+01 5.08710487e-01
#  3.30137943e+01 5.04905964e+01 5.27258741e+00 4.46045636e+00
#  3.98780793e+00 2.63377028e-01 5.43993485e+00 5.76903041e+00
#  9.82760769e+00 6.40526171e+00 2.67255932e+01 9.15618972e+00
#  3.92994416e+00 1.31294860e+01 3.92068432e+01 3.03813388e+00
#  7.39055957e+01 6.02893506e+01 1.10976419e+01 5.85750367e+01
#  2.64720111e+01 8.93098419e+01 1.17670913e+01 1.36795150e+01
#  6.25036317e+00 4.59789528e-02 2.03422541e+01 3.19909960e+01
#  1.40875937e+00 9.45417032e+00 1.73732940e+00 1.27373128e+01
#  1.94415036e+00 1.81437174e+01 6.16007611e+01 1.89702643e+01
#  1.67924626e+01 5.14936214e+00 4.23199866e+01 3.01276347e+00
#  1.73950837e+00 1.18696521e+01 4.52375737e+00 9.00921351e+00
#  3.36652289e+00 8.50372263e+00 1.78168968e+00 9.02129674e+00
#  2.65709456e+00 2.87868993e-01 1.92244876e+01 9.70068557e+00
#  8.03945462e+00 1.31917753e+00 8.05566834e+00 4.54234892e-01
#  1.58399290e+01 8.49492042e+00 1.00332769e+01 6.14393656e+00
#  2.31238240e+01 1.37004615e+01 5.74497259e+01 9.96476002e+00
#  6.35110137e+00 2.34201960e+00 3.79565828e+00 9.01214249e+00
#  2.43683616e-01 1.37551393e+01 3.39307629e+01 6.46806119e+01
#  2.14498042e+01 1.10053234e+01 1.20246133e+01 1.91687027e+01
#  9.33525234e+01 4.37264393e+00 5.43351851e+01 4.66768876e+01
#  1.00444152e+01 6.38877875e+00 4.56262473e+00 1.92961230e+01
#  4.25508371e+00 6.65956472e+01 1.13034809e+01 2.42894146e+01
#  1.14844380e+00 2.61909283e+00 1.13091121e+01 1.30055460e+01
#  1.29391360e+01 9.06162140e+00 8.61824709e+00 2.28578619e+01
#  1.03433693e+01 3.53908649e+00 1.12614542e+01 2.52162456e+00
#  1.03700112e+01 7.94379881e-01 8.54389613e+00 1.13686212e+01
#  9.24536891e+00 6.44465252e+00 9.98495215e+00 9.70731642e+00
#  8.26342080e+00 2.60048981e+00 6.87762895e+01 1.86054842e+01
#  1.77079981e+01 9.94560423e+00 2.24803298e+01 6.06008814e+00
#  9.80263360e+00 1.09226174e+01 1.23301318e+01 8.00108544e+00
#  2.19809355e+00 1.72290310e+01 1.12938701e+01 8.87923662e+01
#  2.99319947e+01 1.11375447e+01 1.43244915e+01 2.92373003e+01
#  1.48734159e+01 1.15023152e+01 1.19360229e+01 1.57778315e+01
#  3.64857352e+00 1.95303287e+01 2.22024700e+00 1.26265144e+00
#  2.27749736e+01 1.20983523e+01 7.67634034e+00 5.12054392e+00
#  1.20157147e+01 1.32541922e+01 1.81547065e+01 5.76550718e+00
#  1.04409008e+01 1.09510780e+00 4.82467495e+01 1.01797407e+01
#  1.10854623e+01 7.20885882e+00 1.25035380e+01 1.41594827e+01
#  1.06855028e+01 3.22031149e+01 6.79743675e+00 2.83037234e+01
#  1.89894180e+01 1.07856581e+01 3.62128777e+00 2.39961154e+01
#  4.48294055e+01 5.77053236e+00 8.20623969e+01 1.36871581e+01
#  1.05589161e+01 9.70573429e+01 2.25233383e+01 2.42957218e+01
#  5.12769629e+01 2.10231177e+00 2.51699418e+00 9.13436905e+00
#  1.23725501e+01 8.46438260e+00 9.81130824e+00 9.44223619e+00
#  7.60303292e+00 6.40732226e+00 1.04124875e+01 3.88882083e+00
#  1.04226192e+01 7.98493045e+00 1.30007329e+01 2.10032164e+01]
